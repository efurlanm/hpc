# %% [markdown]
# # Pyhton is slow
#
# Python is an interpreted language, so it is slow, right? Okay, so let's check how slow it is.
#
# Let's start with a Fortran code compiled with the -O3 flag (optimized), to compare speeds. Fortran is compiled, so it should be much faster, right?
#
# Note: I am not implying that one language is better than another, each tool has its importance and application.
